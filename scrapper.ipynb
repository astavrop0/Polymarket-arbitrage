# %%
import functions
print(functions.__file__)
# Out:
# /Users/ANDREAS/Desktop/polymarket/oddsportal/functions.py

# %%
import sys
import os

print(os.getcwd())
# Out:
# /Users/ANDREAS/Desktop/polymarket/oddsportal

# %%
############ Final oddsportal scraper

# ATP, baseball, basket, darts, eSports, football, nfl, nhl, rugby
''' Create 4 main functions : scrape_historical, scrape_specific_season, scrape current_season, scrape_next_games
NB : You need to be in the right repository to import functions...'''
import os

from functions import *

print('Data will be saved in the following directory:', os.getcwd())
#(tournament='premier-league', sport='soccer', country='england', SEASON='upcoming', nmax=5, include_ou=True, ou_total="2.50")
#(tournament='league-one', sport='soccer', country='england', SEASON='upcoming', nmax=30)
#(tournament='europa-league', sport='soccer', country='europe', SEASON='upcoming', nmax=30)
#(tournament='euroleague', sport='basketball', country='europe', SEASON='upcoming', nmax=30)
#(tournament='khl', sport='hockey', country='russia', SEASON='upcoming', nmax=30)
#(tournament='nba', sport='basketball', country='usa', SEASON='upcoming', nmax=30)
scrape_next_games_typeC(tournament='premier-league', sport='soccer', country='england', SEASON='upcoming', nmax=5, include_ou=True, ou_total="2.50")
# Out:
# Data will be saved in the following directory: /Users/ANDREAS/Desktop/polymarket/oddsportal
# (                      TeamsRaw OddHome OddDraw OddAway    Home_id  \
#  0     16:00 Brighton – Everton    1.87    3.65    4.15   Brighton
#  1        16:00 Leeds – Arsenal    6.24    4.28    1.53      Leeds
#  2   16:00 Wolves – Bournemouth    3.04    3.58    2.27     Wolves
#  3     18:30 Chelsea – West Ham    1.52    4.50    5.97    Chelsea
#  4  21:00 Liverpool – Newcastle    1.81    4.02    4.04  Liverpool
#
#         Away_id         Date
#  0      Everton  31 Jan 2026
#  1      Arsenal
#  2  Bournemouth
#  3     West Ham
#  4    Newcastle               ,
#       Bookmaker Total OddOver OddUnder Payout    Home_id    Away_id  \
#  0        1xBet  +2.5    1.92     2.02  98.4%   Brighton    Everton
#  1        1xbit  +2.5    1.85     1.95  94.9%   Brighton    Everton
#  2        22Bet  +2.5    1.85     1.95  94.9%   Brighton    Everton
#  3     888sport  +2.5    1.83     1.91  93.5%   Brighton    Everton
#  4       bet365  +2.5    1.91     1.91  95.5%   Brighton    Everton
#  ..         ...   ...     ...      ...    ...        ...        ...
#  74    Megapari  +2.5    1.68     2.38  98.5%  Liverpool  Newcastle
#  75  Mozzartbet  +2.5    1.60     2.19  92.5%  Liverpool  Newcastle
#  76      N1 Bet  +2.5    1.60     2.27  93.9%  Liverpool  Newcastle
#  77     Shuffle  +2.5    1.57     2.22  92.0%  Liverpool  Newcastle
#  78   Stake.com  +2.5    1.61     2.28  94.4%  Liverpool  Newcastle
#
#             Date
#  0   31 Jan 2026
#  1   31 Jan 2026
#  2   31 Jan 2026
#  3   31 Jan 2026
#  4   31 Jan 2026
#  ..          ...
#  74
#  75
#  76
#  77
#  78
#
#  [79 rows x 8 columns])
