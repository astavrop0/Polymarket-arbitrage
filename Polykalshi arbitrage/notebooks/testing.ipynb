# %%
# Run the whole pipeline from notebooks/testing.ipynb

import sys
from pathlib import Path
import importlib

# Add project root (the folder that contains "src/") to PYTHONPATH
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

# Reload and run the pipeline (no kernel restart)
import src.run_pipeline as run_pipeline
importlib.reload(run_pipeline)

# Execute
if hasattr(run_pipeline, "main"):
    result = run_pipeline.main()
elif hasattr(run_pipeline, "run"):
    result = run_pipeline.run()
else:
    raise AttributeError("run_pipeline.py must define main() or run()")

result
# Out:
# Fetching Polymarket events with markets...
# Fetching Kalshi events with markets...
#
# Matching events and markets...
#
# ...
# MATCHING COMPLETE
# ...
#
# 📊 EVENT-LEVEL SUMMARY:
# Total matched events: 500
#
# Events by sport:
# sport
# Basketball    300
# Soccer        169
# Hockey         30
# Football        1
# Name: count, dtype: int64
#
# 📊 MARKET-LEVEL SUMMARY:
# Total matched markets: 1036
# Average markets per event: 2.07
#
# ⚠️ DEBUG - EVENTS WITH NO MARKET MATCHES:
# Total events with 0 markets matched: 27
#
# Distribution by sport:
# sport
# Basketball    19
# Soccer         6
# Football       1
# Hockey         1
# Name: count, dtype: int64
#
# First 10 problematic events:
#      sport                                         poly_event                     poly_event_slug                                       kalshi_event                               sample_poly_question                sample_kalshi_title
# ...
